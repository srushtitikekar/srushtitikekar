# %%
import torch
from torch import nn
import torch.utils.data
import torchvision.datasets as data_set
import torchvision.transforms as transforms
from torch import optim
from torch.autograd import Variable
import numpy as np
import torchvision.utils as vutils

# %%
lr=0.0002
epochs=100
batch_size=100

# %%
class Generator(nn.Module):

    def __init__(self,in_channels):
        super(Generator,self).__init__()
        self.fc1=nn.Linear(in_channels,384)

        self.t1=nn.Sequential(
            nn.ConvTranspose2d(in_channels=384,out_channels=192,kernel_size=(4,4),stride=1,padding=0),
            nn.BatchNorm2d(192),
            nn.ReLU()
        )
        self.t2=nn.Sequential(
            nn.ConvTranspose2d(in_channels=192,out_channels=96,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(96),
            nn.ReLU()
        )
        self.t3=nn.Sequential(
            nn.ConvTranspose2d(in_channels=96,out_channels=48,kernel_size=(4,4),stride=2,padding=1),
            nn.BatchNorm2d(48),
            nn.ReLU()
        )
        self.t4=nn.Sequential(
            nn.ConvTranspose2d(in_channels=48,out_channels=3,kernel_size=(4,4),stride=2,padding=1),
            nn.Tanh()
        )
    
    def forward(self,x):
        x=x.view(-1,110)
        x=self.fc1(x)
        x=x.view(-1,384,1,1)
        x=self.t1(x)
        x=self.t2(x)
        x=self.t3(x)
        x=self.t4(x)
        return x

# %%
class Discriminator(nn.Module):
    
    def __init__(self,classes=10):
        
        super(Discriminator,self).__init__()
        self.c1=nn.Sequential(
            nn.Conv2d(in_channels=3,out_channels=16,kernel_size=(3,3),stride=2,padding=1),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c2=nn.Sequential(
            nn.Conv2d(in_channels=16,out_channels=32,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c3=nn.Sequential(
            nn.Conv2d(in_channels=32,out_channels=64,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c4=nn.Sequential(
            nn.Conv2d(in_channels=64,out_channels=128,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c5=nn.Sequential(
            nn.Conv2d(in_channels=128,out_channels=256,kernel_size=(3,3),stride=2,padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.c6=nn.Sequential(
            nn.Conv2d(in_channels=256,out_channels=512,kernel_size=(3,3),stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.5)
            )
        self.fc_source=nn.Linear(4*4*512,1)
        self.fc_class=nn.Linear(4*4*512,classes)
        self.sig=nn.Sigmoid()
        self.soft=nn.Softmax()

    def forward(self,x):

        x=self.c1(x)
        x=self.c2(x)
        x=self.c3(x)
        x=self.c4(x)
        x=self.c5(x)
        x=self.c6(x)
        x=x.view(-1,4*4*512)
        F=self.sig(self.fc_source(x))
        C=self.soft(self.fc_class(x))
        
        return F,C

# %%
real_label = torch.FloatTensor(batch_size).cuda()
real_label.fill_(1)
real_label = real_label.unsqueeze(1)

# %%
fake_label = torch.FloatTensor(batch_size).cuda()
fake_label.fill_(0)
fake_label = fake_label.unsqueeze(1)

# %%
e_noise = torch.FloatTensor(batch_size, 110, 1, 1).normal_(0, 1)
e_noise_ = np.random.normal(0, 1, (batch_size, 110))
e_label = np.random.randint(0, 10, batch_size)
e_onehot = np.zeros((batch_size, 10))
e_onehot[np.arange(batch_size), e_label] = 1
e_noise_[np.arange(batch_size), :10] = e_onehot[np.arange(batch_size)]
e_noise_ = (torch.from_numpy(e_noise_))
e_noise.data.copy_(e_noise_.view(batch_size, 110, 1, 1))
e_noise=e_noise.cuda()

# %%
def calc_acc(preds, labels):
    corr = 0
    pred = preds.data.max(1)[1]
    corr = pred.eq(labels.data).cpu().sum()
    acc = float(corr) / float(len(labels.data)) * 100.0
    return acc

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
            m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
            m.weight.data.normal_(1.0, 0.02)
            m.bias.data.fill_(0)

# %%
dataset = data_set.CIFAR10(root='data/', download=True,transform=transforms.Compose([transforms.Scale((32,32)),transforms.ToTensor(),transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),]))

trainloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
gen=Generator(110).cuda()
disc=Discriminator().cuda()

gen.apply(weights_init)

optimD=optim.Adam(disc.parameters(),lr)
optimG=optim.Adam(gen.parameters(),lr)

source_obj=nn.BCELoss()

class_obj=nn.NLLLoss()

# %%
for epoch in range(epochs):
    for i,data in enumerate(dataloader,0):

        optimD.zero_grad()

        image,label=data
        image,label=image.cuda(),label.cuda()

        source_,class_=disc(image)

        source_error=source_obj(source_,real_label)
        class_error=class_obj(class_,label)
        error_real=source_error+class_error
        error_real.backward()
        optimD.step()


        accuracy=calc_acc(class_,label)

 


        noise_ = np.random.normal(0, 1, (batch_size, 110))

        label=np.random.randint(0,10,batch_size)
        noise=((torch.from_numpy(noise_)).float())
  

        label=((torch.from_numpy(label)).long())
        label=label.cuda()

        noise_image=gen(noise)


        source_,class_=disc(noise_image.detach())
  
        source_error=source_obj(source_,fake_label)
        class_error=class_obj(class_,label)
        error_fake=source_error+class_error
        error_fake.backward()
        optimD.step()




        gen.zero_grad()
        source_,class_=disc(noise_image)
        source_error=source_obj(source_,real_label)
        class_error=class_obj(class_,label)
        error_gen=source_error+class_error
        error_gen.backward()
        optimG.step()
        iteration_now = epoch * len(trainloader) + i

        if i % 100 == 0:
            print("Epoch--[{} / {}], Loss_Discriminator--[{}], Loss_Generator--[{}],Accuracy--[{}]".format(epoch,epochs,error_fake,error_gen,accuracy))
            constructed = gen(e_noise)
            vutils.save_image(
                constructed.data,
                '%s/results_epoch_%03d.png' % ('images/', epoch))
# Out:
# Files already downloaded and verified
# /local_scratch/pbs.533491.pbs02/ipykernel_3541080/1308397674.py:56: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   C=self.soft(self.fc_class(x))
# Epoch--[0 / 100], Loss_Discriminator--[1.3686448335647583], Loss_Generator--[0.11144110560417175],Accuracy--[13.0]
# Epoch--[0 / 100], Loss_Discriminator--[0.22113250195980072], Loss_Generator--[3.429192304611206],Accuracy--[28.999999999999996]
# Epoch--[0 / 100], Loss_Discriminator--[-0.03880634158849716], Loss_Generator--[5.358049392700195],Accuracy--[17.0]
# Epoch--[0 / 100], Loss_Discriminator--[-0.04957768693566322], Loss_Generator--[4.824713706970215],Accuracy--[28.000000000000004]
# Epoch--[0 / 100], Loss_Discriminator--[-0.08053228259086609], Loss_Generator--[6.095004558563232],Accuracy--[27.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.07236895710229874], Loss_Generator--[7.97749662399292],Accuracy--[19.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.06197747588157654], Loss_Generator--[4.30155611038208],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.1107843816280365], Loss_Generator--[9.493159294128418],Accuracy--[26.0]
# Epoch--[1 / 100], Loss_Discriminator--[0.11740000545978546], Loss_Generator--[2.2069497108459473],Accuracy--[30.0]
# Epoch--[1 / 100], Loss_Discriminator--[-0.1285061240196228], Loss_Generator--[8.351152420043945],Accuracy--[34.0]
# Epoch--[2 / 100], Loss_Discriminator--[0.053901270031929016], Loss_Generator--[3.511756658554077],Accuracy--[23.0]
# Epoch--[2 / 100], Loss_Discriminator--[-0.1285025179386139], Loss_Generator--[5.262381076812744],Accuracy--[28.000000000000004]
# Epoch--[2 / 100], Loss_Discriminator--[0.1408880650997162], Loss_Generator--[5.125026702880859],Accuracy--[24.0]
# Epoch--[2 / 100], Loss_Discriminator--[-0.022828400135040283], Loss_Generator--[4.142895698547363],Accuracy--[25.0]
# Epoch--[2 / 100], Loss_Discriminator--[-0.05557402968406677], Loss_Generator--[5.503149509429932],Accuracy--[30.0]
# Epoch--[3 / 100], Loss_Discriminator--[-0.10763374716043472], Loss_Generator--[6.889965057373047],Accuracy--[20.0]
# Epoch--[3 / 100], Loss_Discriminator--[-0.09647943079471588], Loss_Generator--[9.325165748596191],Accuracy--[32.0]
# Epoch--[3 / 100], Loss_Discriminator--[-0.11696929484605789], Loss_Generator--[6.815884590148926],Accuracy--[26.0]
# Epoch--[3 / 100], Loss_Discriminator--[0.01424454152584076], Loss_Generator--[6.880293369293213],Accuracy--[27.0]
# Epoch--[3 / 100], Loss_Discriminator--[-0.0517762266099453], Loss_Generator--[6.905369758605957],Accuracy--[31.0]
# Epoch--[4 / 100], Loss_Discriminator--[-0.10246013849973679], Loss_Generator--[3.460876226425171],Accuracy--[23.0]
# Epoch--[4 / 100], Loss_Discriminator--[0.5289228558540344], Loss_Generator--[3.9740149974823],Accuracy--[34.0]
# Epoch--[4 / 100], Loss_Discriminator--[-0.04887021332979202], Loss_Generator--[6.682588577270508],Accuracy--[32.0]
# Epoch--[4 / 100], Loss_Discriminator--[0.4878797233104706], Loss_Generator--[5.111621379852295],Accuracy--[25.0]
# Epoch--[4 / 100], Loss_Discriminator--[-0.027679841965436935], Loss_Generator--[3.980781078338623],Accuracy--[36.0]
# Epoch--[5 / 100], Loss_Discriminator--[-0.07529395818710327], Loss_Generator--[8.817937850952148],Accuracy--[27.0]
# Epoch--[5 / 100], Loss_Discriminator--[-0.13264994323253632], Loss_Generator--[7.903807640075684],Accuracy--[36.0]
# Epoch--[5 / 100], Loss_Discriminator--[-0.059758782386779785], Loss_Generator--[7.126701354980469],Accuracy--[28.000000000000004]
# Epoch--[5 / 100], Loss_Discriminator--[-0.06911428272724152], Loss_Generator--[4.747245788574219],Accuracy--[28.000000000000004]
# Epoch--[5 / 100], Loss_Discriminator--[-0.10088462382555008], Loss_Generator--[10.37401294708252],Accuracy--[32.0]
# Epoch--[6 / 100], Loss_Discriminator--[-0.00533662736415863], Loss_Generator--[4.2402119636535645],Accuracy--[19.0]
# Epoch--[6 / 100], Loss_Discriminator--[-0.0724039152264595], Loss_Generator--[5.976175308227539],Accuracy--[30.0]
# Epoch--[6 / 100], Loss_Discriminator--[-0.003419041633605957], Loss_Generator--[4.5785980224609375],Accuracy--[23.0]
# Epoch--[6 / 100], Loss_Discriminator--[0.05430096387863159], Loss_Generator--[5.9520583152771],Accuracy--[30.0]
# Epoch--[6 / 100], Loss_Discriminator--[0.3671402931213379], Loss_Generator--[4.283371925354004],Accuracy--[34.0]
# Epoch--[7 / 100], Loss_Discriminator--[3.875755786895752], Loss_Generator--[0.7243978381156921],Accuracy--[23.0]
# Epoch--[7 / 100], Loss_Discriminator--[-0.07815223932266235], Loss_Generator--[6.196842193603516],Accuracy--[32.0]
# Epoch--[7 / 100], Loss_Discriminator--[-0.08390948921442032], Loss_Generator--[13.000836372375488],Accuracy--[28.000000000000004]
# Epoch--[7 / 100], Loss_Discriminator--[-0.1266002357006073], Loss_Generator--[13.6546630859375],Accuracy--[28.999999999999996]
# Epoch--[7 / 100], Loss_Discriminator--[0.009167596697807312], Loss_Generator--[4.379958152770996],Accuracy--[40.0]
# Epoch--[8 / 100], Loss_Discriminator--[-0.07788880169391632], Loss_Generator--[6.907760143280029],Accuracy--[27.0]
# Epoch--[8 / 100], Loss_Discriminator--[0.10501104593276978], Loss_Generator--[5.001322269439697],Accuracy--[37.0]
# Epoch--[8 / 100], Loss_Discriminator--[-0.10144740343093872], Loss_Generator--[12.181435585021973],Accuracy--[26.0]
# Epoch--[8 / 100], Loss_Discriminator--[-0.05727504938840866], Loss_Generator--[10.789558410644531],Accuracy--[27.0]
# Epoch--[8 / 100], Loss_Discriminator--[0.05256977677345276], Loss_Generator--[3.43735408782959],Accuracy--[38.0]
# Epoch--[9 / 100], Loss_Discriminator--[-0.06967419385910034], Loss_Generator--[10.033556938171387],Accuracy--[32.0]
# Epoch--[9 / 100], Loss_Discriminator--[0.28275299072265625], Loss_Generator--[2.462172508239746],Accuracy--[37.0]
# Epoch--[9 / 100], Loss_Discriminator--[0.3198767602443695], Loss_Generator--[4.070417881011963],Accuracy--[28.000000000000004]
# Epoch--[9 / 100], Loss_Discriminator--[-0.16433048248291016], Loss_Generator--[12.178296089172363],Accuracy--[33.0]
# Epoch--[9 / 100], Loss_Discriminator--[-0.10187043994665146], Loss_Generator--[16.428466796875],Accuracy--[35.0]
# Epoch--[10 / 100], Loss_Discriminator--[-0.07207271456718445], Loss_Generator--[3.5804238319396973],Accuracy--[28.999999999999996]
# Epoch--[10 / 100], Loss_Discriminator--[0.010722652077674866], Loss_Generator--[4.371165752410889],Accuracy--[28.000000000000004]
# Epoch--[10 / 100], Loss_Discriminator--[-0.09872906655073166], Loss_Generator--[8.926658630371094],Accuracy--[26.0]
# Epoch--[10 / 100], Loss_Discriminator--[0.21803691983222961], Loss_Generator--[4.200769901275635],Accuracy--[28.000000000000004]
# Epoch--[10 / 100], Loss_Discriminator--[-0.05740031972527504], Loss_Generator--[6.215643882751465],Accuracy--[39.0]
# Epoch--[11 / 100], Loss_Discriminator--[-0.07270700484514236], Loss_Generator--[8.358698844909668],Accuracy--[27.0]
# Epoch--[11 / 100], Loss_Discriminator--[1.680275559425354], Loss_Generator--[2.3391339778900146],Accuracy--[31.0]
# Epoch--[11 / 100], Loss_Discriminator--[0.19367152452468872], Loss_Generator--[3.6002485752105713],Accuracy--[27.0]
# Epoch--[11 / 100], Loss_Discriminator--[-0.11584602296352386], Loss_Generator--[7.94174861907959],Accuracy--[34.0]
# Epoch--[11 / 100], Loss_Discriminator--[-0.07361121475696564], Loss_Generator--[9.034364700317383],Accuracy--[41.0]
# Epoch--[12 / 100], Loss_Discriminator--[-0.026154741644859314], Loss_Generator--[3.399103879928589],Accuracy--[28.000000000000004]
# Epoch--[12 / 100], Loss_Discriminator--[0.11638151109218597], Loss_Generator--[6.92622184753418],Accuracy--[37.0]
# Epoch--[12 / 100], Loss_Discriminator--[-0.12040170282125473], Loss_Generator--[12.833738327026367],Accuracy--[28.000000000000004]
# Epoch--[12 / 100], Loss_Discriminator--[0.0806361511349678], Loss_Generator--[3.965134620666504],Accuracy--[30.0]
# Epoch--[12 / 100], Loss_Discriminator--[-0.08086152374744415], Loss_Generator--[6.21273136138916],Accuracy--[40.0]
# Epoch--[13 / 100], Loss_Discriminator--[-0.07607875764369965], Loss_Generator--[11.492138862609863],Accuracy--[27.0]
# Epoch--[13 / 100], Loss_Discriminator--[-0.036974601447582245], Loss_Generator--[6.258955955505371],Accuracy--[35.0]
# Epoch--[13 / 100], Loss_Discriminator--[-0.016586124897003174], Loss_Generator--[5.415024280548096],Accuracy--[24.0]
# Epoch--[13 / 100], Loss_Discriminator--[-0.04363304376602173], Loss_Generator--[5.151549816131592],Accuracy--[26.0]
# Epoch--[13 / 100], Loss_Discriminator--[0.045987509191036224], Loss_Generator--[5.841161727905273],Accuracy--[38.0]
# Epoch--[14 / 100], Loss_Discriminator--[0.40984591841697693], Loss_Generator--[3.136606454849243],Accuracy--[33.0]
# Epoch--[14 / 100], Loss_Discriminator--[0.16850927472114563], Loss_Generator--[4.225929260253906],Accuracy--[32.0]
# Epoch--[14 / 100], Loss_Discriminator--[-0.05889323353767395], Loss_Generator--[8.107674598693848],Accuracy--[27.0]
# Epoch--[14 / 100], Loss_Discriminator--[-0.02821873128414154], Loss_Generator--[8.862908363342285],Accuracy--[33.0]
# Epoch--[14 / 100], Loss_Discriminator--[-0.11000389605760574], Loss_Generator--[6.015105247497559],Accuracy--[41.0]
# Epoch--[15 / 100], Loss_Discriminator--[0.08130679279565811], Loss_Generator--[4.474970817565918],Accuracy--[36.0]
# Epoch--[15 / 100], Loss_Discriminator--[-0.09039542078971863], Loss_Generator--[7.243272304534912],Accuracy--[35.0]
# Epoch--[15 / 100], Loss_Discriminator--[-0.055769264698028564], Loss_Generator--[6.638977527618408],Accuracy--[31.0]
# Epoch--[15 / 100], Loss_Discriminator--[-0.0923604965209961], Loss_Generator--[9.275501251220703],Accuracy--[38.0]
# Epoch--[15 / 100], Loss_Discriminator--[-0.11581259220838547], Loss_Generator--[13.347098350524902],Accuracy--[45.0]
# Epoch--[16 / 100], Loss_Discriminator--[-0.13834133744239807], Loss_Generator--[3.8118700981140137],Accuracy--[31.0]
# Epoch--[16 / 100], Loss_Discriminator--[0.11226215213537216], Loss_Generator--[5.765011787414551],Accuracy--[35.0]
# Epoch--[16 / 100], Loss_Discriminator--[-0.02412472479045391], Loss_Generator--[4.986968040466309],Accuracy--[32.0]
# Epoch--[16 / 100], Loss_Discriminator--[-0.03715306520462036], Loss_Generator--[4.408650875091553],Accuracy--[32.0]
# Epoch--[16 / 100], Loss_Discriminator--[0.6491938829421997], Loss_Generator--[5.608954906463623],Accuracy--[37.0]
# Epoch--[17 / 100], Loss_Discriminator--[-0.059036511927843094], Loss_Generator--[7.835155010223389],Accuracy--[28.999999999999996]
# Epoch--[17 / 100], Loss_Discriminator--[-0.06966108083724976], Loss_Generator--[7.601653099060059],Accuracy--[40.0]
# Epoch--[17 / 100], Loss_Discriminator--[-0.06434501707553864], Loss_Generator--[9.324966430664062],Accuracy--[28.999999999999996]
# Epoch--[17 / 100], Loss_Discriminator--[0.3901178538799286], Loss_Generator--[4.075875759124756],Accuracy--[36.0]
# Epoch--[17 / 100], Loss_Discriminator--[3.122887134552002], Loss_Generator--[4.583098411560059],Accuracy--[37.0]
# Epoch--[18 / 100], Loss_Discriminator--[0.42424026131629944], Loss_Generator--[5.168961524963379],Accuracy--[32.0]
# Epoch--[18 / 100], Loss_Discriminator--[-0.148712620139122], Loss_Generator--[15.2212495803833],Accuracy--[35.0]
# Epoch--[18 / 100], Loss_Discriminator--[-0.1107635498046875], Loss_Generator--[12.085357666015625],Accuracy--[31.0]
# Epoch--[18 / 100], Loss_Discriminator--[-0.07350045442581177], Loss_Generator--[7.038058280944824],Accuracy--[39.0]
# Epoch--[18 / 100], Loss_Discriminator--[0.1832611858844757], Loss_Generator--[4.338109016418457],Accuracy--[41.0]
# Epoch--[19 / 100], Loss_Discriminator--[-0.1011575236916542], Loss_Generator--[13.800342559814453],Accuracy--[31.0]
# Epoch--[19 / 100], Loss_Discriminator--[-0.062360771000385284], Loss_Generator--[6.356862545013428],Accuracy--[36.0]
# Epoch--[19 / 100], Loss_Discriminator--[0.043820470571517944], Loss_Generator--[5.085021018981934],Accuracy--[33.0]
# Epoch--[19 / 100], Loss_Discriminator--[-0.06263991445302963], Loss_Generator--[11.423563003540039],Accuracy--[32.0]
# Epoch--[19 / 100], Loss_Discriminator--[-0.06399653106927872], Loss_Generator--[8.832066535949707],Accuracy--[41.0]
# Epoch--[20 / 100], Loss_Discriminator--[-0.08789896965026855], Loss_Generator--[7.750357627868652],Accuracy--[34.0]
# Epoch--[20 / 100], Loss_Discriminator--[-0.09808746725320816], Loss_Generator--[8.452069282531738],Accuracy--[32.0]
# Epoch--[20 / 100], Loss_Discriminator--[0.06052018702030182], Loss_Generator--[5.491738796234131],Accuracy--[25.0]
# Epoch--[20 / 100], Loss_Discriminator--[-0.08256280422210693], Loss_Generator--[2.952008008956909],Accuracy--[26.0]
# Epoch--[20 / 100], Loss_Discriminator--[-0.06978081166744232], Loss_Generator--[7.452996730804443],Accuracy--[44.0]
# Epoch--[21 / 100], Loss_Discriminator--[-0.07508660107851028], Loss_Generator--[11.56434440612793],Accuracy--[33.0]
# Epoch--[21 / 100], Loss_Discriminator--[-0.014542046934366226], Loss_Generator--[5.593249797821045],Accuracy--[35.0]
# Epoch--[21 / 100], Loss_Discriminator--[-0.08379151672124863], Loss_Generator--[5.90262508392334],Accuracy--[28.999999999999996]
# Epoch--[21 / 100], Loss_Discriminator--[4.227299690246582], Loss_Generator--[5.7744245529174805],Accuracy--[34.0]
# Epoch--[21 / 100], Loss_Discriminator--[-0.05460410565137863], Loss_Generator--[6.8821516036987305],Accuracy--[38.0]
# Epoch--[22 / 100], Loss_Discriminator--[-0.11038036644458771], Loss_Generator--[10.417475700378418],Accuracy--[31.0]
# Epoch--[22 / 100], Loss_Discriminator--[0.27940183877944946], Loss_Generator--[5.176346778869629],Accuracy--[31.0]
# Epoch--[22 / 100], Loss_Discriminator--[-0.07150296866893768], Loss_Generator--[7.236868858337402],Accuracy--[30.0]
# Epoch--[22 / 100], Loss_Discriminator--[-0.11647788435220718], Loss_Generator--[13.939289093017578],Accuracy--[28.999999999999996]
# Epoch--[22 / 100], Loss_Discriminator--[-0.1230037659406662], Loss_Generator--[4.898069858551025],Accuracy--[42.0]
# Epoch--[23 / 100], Loss_Discriminator--[0.12590543925762177], Loss_Generator--[4.900482654571533],Accuracy--[23.0]
